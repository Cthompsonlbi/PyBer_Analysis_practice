# %%
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
savings = [0 , 100, 220,300,500,660]
months = ["Jan","Feb","Mar","April","May","June"]
plt.plot(months, savings)
plt.xlabel("Month")
plt.ylabel("Savings in Dollars")
plt.title("Saving Account Results")
plt.show()
